# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 1. Import the penguin dataset https://raw.githubusercontent.com/allisonhorst/palmerpenguins/master/inst/extdata/penguins.csv

# %%
penguins = pd.read_csv('https://raw.githubusercontent.com/allisonhorst/palmerpenguins/master/inst/extdata/penguins.csv')

# %% [markdown]
# 2. Create a new columns called ```body_mass_kg``` by transforming the ```body_mass_g``` column into kilograms.

# %%
penguins['body_mass_kg'] = penguins['body_mass_g']/1000
penguins.head(3)
# Out:
#   species     island  bill_length_mm  ...  year  body_mass_kg     ratio
# 0  Adelie  Torgersen            39.1  ...  2007          3.75  2.090909
# 1  Adelie  Torgersen            39.5  ...  2007          3.80  2.270115
# 2  Adelie  Torgersen            40.3  ...  2007          3.25  2.238889
#
# [3 rows x 10 columns]

# %% [markdown]
# 3. Create a new column containiing the division the ```bill_length_mm``` by the ```bill_depth_mm``` column

# %%
penguins['ratio'] = penguins['bill_length_mm'] / penguins['bill_depth_mm']
penguins.head(3)
# Out:
#   species     island  bill_length_mm  ...  year  body_mass_kg     ratio
# 0  Adelie  Torgersen            39.1  ...  2007          3.75  2.090909
# 1  Adelie  Torgersen            39.5  ...  2007          3.80  2.270115
# 2  Adelie  Torgersen            40.3  ...  2007          3.25  2.238889
#
# [3 rows x 10 columns]

# %% [markdown]
# 4. Calculate the median value of the ```body_mass_g``` column both by using a Numpy function and by using the method attached to the column. What do you observe? Can you infer what the problem is?

# %%
np.median(penguins['body_mass_g'])
# Out:
# nan

# %% [markdown]
# Since some of the elements of the column are ```NaN```, Numpy cannot calculate the median. We would have to use a specific function that properly handles ```Nan``` values:

# %%
np.nanmedian(penguins['body_mass_g'])
# Out:
# 4050.0

# %%
penguins['body_mass_g'].median()
# Out:
# 4050.0

# %% [markdown]
# In contrast, Pandas knows by default how to deal with missing values.
