# %% [markdown]
# 1. Try to import this image: https://upload.wikimedia.org/wikipedia/commons/5/5b/Serengeti_Elefantenherde1.jpg?download

# %%
im_elefant = skimage.io.imread('https://upload.wikimedia.org/wikipedia/commons/5/5b/Serengeti_Elefantenherde1.jpg?download')

# %% [markdown]
# 2. What are the dimensions of the image? Do you know what the dimensions are ?

# %%
im_elefant.shape
# Out:
# (2550, 3825, 3)

# %% [markdown]
# This is a natural image composed of Red, Green and Blue channels. Therefore the image has three planes, one per color.

# %% [markdown]
# 3. Display just the last channel:

# %%
plt.imshow(im_elefant[:,:,2])

# %% [markdown]
# 4. Try to crop the left-most elefant and display it in the first channel:

# %%
im_crop = im_elefant[1000:1800,0:600,2].copy()

# %%
plt.imshow(im_crop);

# %% [markdown]
# 5. Create a thresholed image where only the elefant tooth is visible

# %%
im_tooth = im_crop > 210

# %%
plt.imshow(im_tooth);
