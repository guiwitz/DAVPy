# %%
import pandas as pd

# %% [markdown]
# 1. Try to import this file from GitHub: https://github.com/allisonhorst/palmerpenguins/blob/master/inst/extdata/penguins.csv

# %%
pd.read_csv('https://github.com/allisonhorst/palmerpenguins/blob/master/inst/extdata/penguins.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-5-b104910ebe4a> in <module>()
# ----> 1 pd.read_csv('https://github.com/allisonhorst/palmerpenguins/blob/master/inst/extdata/penguins.csv')
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
# ...

# %% [markdown]
# 2. Does the import work with the link provided? If not visit the link and see if you can access the **raw data** and the corresponding address.

# %%
penguins = pd.read_csv('https://raw.githubusercontent.com/allisonhorst/palmerpenguins/master/inst/extdata/penguins.csv')

# %% [markdown]
# 3. Use the ```head``` method to see the first 6 elements of the table.

# %%
penguins.head(6)
# Out:
#   species     island  bill_length_mm  ...  body_mass_g     sex  year
# 0  Adelie  Torgersen            39.1  ...       3750.0    male  2007
# 1  Adelie  Torgersen            39.5  ...       3800.0  female  2007
# 2  Adelie  Torgersen            40.3  ...       3250.0  female  2007
# 3  Adelie  Torgersen             NaN  ...          NaN     NaN  2007
# 4  Adelie  Torgersen            36.7  ...       3450.0  female  2007
# 5  Adelie  Torgersen            39.3  ...       3650.0    male  2007
#
# [6 rows x 8 columns]

# %% [markdown]
# 4. Can you find a method (function attached to the object) to calculate only means in the table?

# %%
penguins.mean()
# Out:
# bill_length_mm         43.921930
# bill_depth_mm          17.151170
# flipper_length_mm     200.915205
# body_mass_g          4201.754386
# year                 2008.029070
# dtype: float64

# %% [markdown]
# 5. What do you observe in the result? Are some columns missing?

# %% [markdown]
# Non-numerical columns are automatically discarded.
