# %%
import numpy as np

# %% [markdown]
# 1. Create a numpy array with values from 0 to 10 in steps of 0.5

# %%
test_array = np.arange(0, 10, 0.5)

# %% [markdown]
# 2. Extract the the last three elements of the array (without manually setting the array length).

# %%
len_array = test_array.shape[0]
len_array
# Out:
# 20

# %%
test_array[len_array-3::]
# Out:
# array([8.5, 9. , 9.5])

# %% [markdown]
# 3. Apply a cosine function to the array and store the output in a new array.

# %%
cos_array = np.cos(test_array)

# %% [markdown]
# 4. Create a boolean array telling which values in the array from (2) are smaller than 0.

# %%
sel_array = cos_array < 0
sel_array
# Out:
# array([False, False, False, False,  True,  True,  True,  True,  True,
#         True, False, False, False, False, False, False,  True,  True,
#         True,  True])

# %% [markdown]
# 5. Recover only those values in a new array via indexing.

# %%
values = cos_array[sel_array]
values
# Out:
# array([-0.41614684, -0.80114362, -0.9899925 , -0.93645669, -0.65364362,
#        -0.2107958 , -0.14550003, -0.6020119 , -0.91113026, -0.99717216])
